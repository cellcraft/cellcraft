# %%
import minecraft_api
import importlib
importlib.reload(minecraft_api) 
minecraft_api.minecraft_api(['asdasd','cellpack','test6.x3d',4,20])

# %%
import pandas as pd
from src.protein import *

# %%
df = pd.read_csv('../x3d/test6.csv')
df.pdbid = df.pdbid.str.replace('\'', '')
df.pdbid = df.pdbid.str.upper()
df2 = df[~df.Gosom.isnull()]
df2

# %%
GObioproc = {}
GOmolefunt = {}
GOcellcomp = {}

df2 = df[~df.Gosom.isnull()]
for i in range(df2.shape[0]):
    row = df2.iloc[i]
    Protcomplex = protein_complex(row.pdbid)
    Protcomplex.get_PDB()
    Protcomplex.clean_pdb()
    Protcomplex.split_complex()
    Protcomplex.load_chain_info()
    

    for p in Protcomplex.proteins:
        for func in p.GObioproc:
            if func in GObioproc:
                GObioproc[func] += row.nItems
            else:
                GObioproc[func] = row.nItems
        for func in p.GOmolefunt:
            if func in GOmolefunt:
                GOmolefunt[func] += row.nItems
            else:
                GOmolefunt[func] = row.nItems
        for func in p.GOcellcomp:
            if func in GOcellcomp:
                GOcellcomp[func] += row.nItems
            else:
                GOcellcomp[func] = row.nItems

# %% [raw]
# print(GObioproc)

# %%
print(GObioproc)
print(GOmolefunt)
print(GOcellcomp)
pd.DataFrame.from_dict(GObioproc,orient='index').to_csv('GObioproc.csv')
pd.DataFrame.from_dict(GOmolefunt,orient='index').to_csv('GOmolefunt.csv')
pd.DataFrame.from_dict(GOcellcomp,orient='index').to_csv('GOcellcomp.csv')

# %%
pd.DataFrame.from_dict(GObioproc,orient='index').to_csv('GObioproc.csv')
pd.DataFrame.from_dict(GOmolefunt,orient='index').to_csv('GOmolefunt.csv')
pd.DataFrame.from_dict(GOcellcomp,orient='index').to_csv('GOcellcomp.csv')

# %%
names = ['cellular component','shit1','shit2','molecular function','shit3','shit4','biological processes']

d = {'name':'GOterms',
    'children':[]}
for dic,name in zip([GOcellcomp,{},{},GOmolefunt,{},{},GObioproc],names):
    gd = {'name':name,
        'children':[{'name':name,
        'children':[]}]}
    for term in dic.items():
        tg = {'name':term[0],'size':int(term[1])}
        gd['children'][0]['children'].append(tg)
    d['children'].append(gd)

print(d)
import json
with open('HIV.json', 'w') as fp:
    json.dump(d, fp)

# %%
{
 "name": "flare",
 "children": [
  {
   "name": "analytics",
   "children": [
    {
     "name": "cluster",
     "children": [
      {"name": "AgglomerativeCluster", "size": 3938},
      {"name": "CommunityStructure", "size": 3812},
      {"name": "HierarchicalCluster", "size": 6714},
      {"name": "MergeEdge", "size": 743}
     ]
    },
    {
     "name": "graph",
     "children": [
      {"name": "BetweennessCentrality", "size": 3534},
      {"name": "LinkDistance", "size": 5731},
      {"name": "MaxFlowMinCut", "size": 7840},
      {"name": "ShortestPaths", "size": 5914},
      {"name": "SpanningTree", "size": 3416}
     ]
    },
    {
     "name": "optimization",
     "children": [
      {"name": "AspectRatioBanker", "size": 7074}
     ]

# %%
df

# %%
# 70           NaN     NaN      NaN           NaN           NaN    1945
# 71           NaN     NaN      NaN           NaN           NaN    1943
# 72           NaN     NaN      NaN           NaN           NaN    1942
# 73           NaN     NaN      NaN           NaN           NaN    1938
# 74           NaN     NaN      NaN           NaN           NaN    1937
# 75           NaN     NaN      NaN           NaN           NaN    1936
# 76           NaN     NaN      NaN           NaN           NaN    1935
# 77           NaN     NaN      NaN           NaN           NaN    1934
# 78           NaN     NaN      NaN           NaN           NaN    1931
# 79           NaN     NaN      NaN           NaN           NaN    1928
# 80           NaN     NaN      NaN           NaN           NaN    1927
# 81           NaN     NaN      NaN           NaN           NaN    1925
# 82           NaN     NaN      NaN           NaN           NaN    1923
# 83           NaN     NaN      NaN           NaN           NaN    1922
# 84           NaN     NaN      NaN           NaN           NaN    1920
# 85           NaN     NaN      NaN           NaN           NaN    1919
# 86           NaN     NaN      NaN           NaN           NaN    1917
#
#     count.3  cumulative.3  percentage.3
# 0      2494        449481    100.000000
# 1     44645        446987     99.445138
# 2     38174        402342     89.512571
# 3     25496        364168     81.019665
# 4     23701        338672     75.347345
# 5     22007        314971     70.074375
# 6     20772        292964     65.178283
# 7     19259        272192     60.556953
# 8     18935        252933     56.272234
# 9     17720        233998     52.059598
# 10    17206        216278     48.117273
# 11    16348        199072     44.289303
# 12    15882        182724     40.652219
# 13    14703        166842     37.118810
# 14    14135        152139     33.847704
# 15    13474        138004     30.702966
# 16    12796        124530     27.705287
# 17    11617        111734     24.858448
# 18    10860        100117     22.273911
# 19     9852         89257     19.857792
# 20     9665         79405     17.665930
# 21     9299         69740     15.515673
# 22     8551         60441     13.446842
# 23     8212         51890     11.544426
# 24     7913         43678      9.717430
# 25     7182         35765      7.956955
# 26     6552         28583      6.359112
# 27     5814         22031      4.901431
# 28     5105         16217      3.607939
# 29     2257         11112      2.472185
# ..      ...           ...           ...
# 57       57           296      0.065854
# 58       23           239      0.053172
# 59       26           216      0.048055
# 60       29           190      0.042271
# 61       22           161      0.035819
# 62       25           139      0.030925
# 63       24           114      0.025363
# 64       15            90      0.020023
# 65       12            75      0.016686
# 66       14            63      0.014016
# 67       17            49      0.010901
# 68        4            32      0.007119
# 69        1            28      0.006229
# 70        1            27      0.006007
# 71        1            26      0.005784
# 72        1            25      0.005562
# 73        1            24      0.005339
# 74        1            23      0.005117
# 75        1            22      0.004895
# 76        1            21      0.004672
# 77        2            20      0.004450
# 78        2            18      0.004005
# 79        6            16      0.003560
# 80        2            10      0.002225
# 81        1             8      0.001780
# 82        1             7      0.001557
# 83        2             6      0.001335
# 84        2             4      0.000890
# 85        1             2      0.000445
# 86        1             1      0.000222
#
# [87 rows x 16 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import matplotlib

mdata = pd.read_csv('/home/lbrinkm/Downloads/timeline.csv')
mdata = mdata[~(mdata.year > 2015)]
j1 = mdata.loc[~mdata['year'].isnull(),['year','percentage']]
j2 = mdata.loc[~mdata['year.1'].isnull(),['year.1','percentage.1']]
j3 = mdata.loc[~mdata['year.2'].isnull(),['year.2','percentage.2']]
j4 = mdata.loc[~mdata['year.3'].isnull(),['year.3','percentage.3']]

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)
plt.plot(j1['year'].tolist(),j1['percentage'].tolist()/j1['percentage'].tolist()[11],lw=3)
plt.plot(j2['year.1'].tolist(),j2['percentage.1'].tolist()/j2['percentage.1'].tolist()[11],lw=3)
plt.plot(j3['year.2'].tolist(),j3['percentage.2'].tolist()/j3['percentage.2'].tolist()[11],lw=3)
plt.plot(j4['year.3'].tolist(),j4['percentage.3'].tolist()/j4['percentage.3'].tolist()[11],lw=3)

plt.xlim(1970,2018)

plt.legend(['bioinformatics', 'biophysics', 'computational biology', 'cell biology'], loc='upper left')
plt.savefig("Graph2.pdf")
plt.clf()
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:1287: UserWarning: findfont: Font family ['normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np

colnames = ['year', 'nSequences']
mdata = pd.read_csv('/home/lbrinkm/Downloads/yearNstruckNseq.csv', names=colnames)

year = mdata.year.tolist()
nseq = mdata.nSequences.as_matrix()
print(year,nseq)    


x=[1971, 2000, 2005, 2010, 2015, 2016]
y=np.array([7, 10971, 39689, 101530, 206878, 321663])

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)
plt.plot(year,nseq,lw=3)
plt.plot(x[:-1],y[:-1]*10,lw=3)

plt.xlim(1970,2018)

plt.legend(['Sequences', 'PDB'], loc='upper left')
plt.savefig("Graph3.pdf")
plt.clf()
# Out:
# [1971, 1985, 1990, 1995, 2001, 2006, 2011, 2014, 2015] [         0      30055     484457    5652113  126454207 1004300021
#  3810112039 6619270271 8609310936]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-a23888d38c8a> in <module>()
#      18 matplotlib.rc('font', **font)
#      19 plt.plot(year,nseq,lw=3)
# ---> 20 plt.plot(x[:-1],y[:-1]*10,lw=3)
#      21
#      22 plt.xlim(1970,2018)
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1425             kwargs['color'] = c
#    1426
# -> 1427         for line in self._get_lines(*args, **kwargs):
#    1428             self.add_line(line)
#    1429             lines.append(line)
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     384                 return
#     385             if len(remaining) <= 3:
# --> 386                 for seg in self._plot_args(remaining, kwargs):
#     387                     yield seg
#     388                 return
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     362             x, y = index_of(tup[-1])
#     363
# --> 364         x, y = self._xy_from_xy(x, y)
#     365
#     366         if self.command == 'plot':
#
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     221         y = _check_1d(y)
#     222         if x.shape[0] != y.shape[0]:
# --> 223             raise ValueError("x and y must have same first dimension")
#     224         if x.ndim > 2 or y.ndim > 2:
#     225             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension
